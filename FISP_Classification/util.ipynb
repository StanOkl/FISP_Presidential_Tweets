# %%
# coding: utf-8

# In[80]:

import csv
import os
import re
from collections import defaultdict

DATA_DIR = 'data/'

category = ['No_Policy_Content',
        'Macroeconomic_Policy___Taxes__Gov__Spending__Wall_St___Jobs__Trade__Infrastructure__Labor_',
        'Education',
        'National_Security__Veterans__Military__Foreign_Terrorism_',
        'Immigration',
        'Civil_Rights__Race__LGBT_issues__Abortion__Gender_issues_',
        'Environment___Energy__Global_warming__Fracking__Agriculture__Oil_',
        'Crime___Law_Enforcement__Police__Guns__Second_Amendment_',
        'Health_Care__Obamacare_',
        'Governance']

def process_text(text):
    text = re.sub('http.*?\s', 'http ', text)
    text = re.sub('http.*?$', 'http ', text)
    text = text.lower()
    text = text.translate(None, string.punctuation)
    return text

# %%
import random
def load_data1():
    data_dir = 'raw_data/'
    files = filter(lambda x: x.endswith('.csv'),os.listdir(data_dir))

    header = []
    data = []
    for f in files:
        with open(data_dir+f) as data_in:
            reader = csv.reader(data_in)
            new_header = reader.next()
            header.extend(new_header)
            for l in reader:
                tweet = dict(zip(new_header,l))
                data.append(tweet)
    classifications = defaultdict(list)
    count = 0
    for tweet in data:
        single_tweet = defaultdict(list)
        text = tweet['text']
        for key,val in tweet.items():
            if key.startswith('coder1') or key.startswith('coder2'):

                key = key.replace('coder1.','')
                key = key.replace('coder2.','')
                key = key.replace('.','_')

                # skip coder, it's not a label
                if key == 'coder':
                    continue
                
                if key in category:
                    if val == '1':
                        single_tweet['Policy'].append(int(category.index(key)))
                else:
                    single_tweet[key].append(val)

        for key in single_tweet:
            if len(single_tweet[key]) == 2:
                if single_tweet[key][0] != single_tweet[key][1]:
#                     if random.random() > 0.5:
#                         classifications[key].append([text, single_tweet[key][0]])
#                     else:
#                         classifications[key].append([text, single_tweet[key][1]])
                    continue
                else:
                    classifications[key].append([text, single_tweet[key][0]])
            else:
                classifications[key].append([text, single_tweet[key][0]])
    return classifications

# %%
def save_data():
    classifications = load_data()
    for key, val in classifications.items():
        with open(DATA_DIR+key+'.csv', 'w') as f:
            writer = csv.writer(f)
            writer.writerows(val)

# %%
# In[81]:

def load_data2():
    data_dir = 'raw_data2/'
    files = filter(lambda x: x.endswith('.csv'),os.listdir(data_dir))
    header = []
    data = []
    classifications = defaultdict(list)
    for f in files:
        with open(data_dir+f) as data_in:
            reader = csv.reader(data_in)
            new_header = reader.next()
            header.extend(new_header)
            for l in reader:
                tweet = dict(zip(new_header,l))
                data.append(tweet)

    classifications = defaultdict(list)
    
    for tweet in data:
        text = tweet['text']
        try:
            text.decode('utf-8')
        except:
            continue
        single_tweet = {}
        for key, val in tweet.items():
            if key in ['id', 'created_at', 'text']:
                continue
            
            key = key.replace('.','_')
            
            if val == 'NA':
                val = '0'
            
            if key in category:
                if val == '1':
                    single_tweet['Policy'] = int(category.index(key))
            else:
                single_tweet[key] = val
        for key in single_tweet:
            classifications[key].append([text, single_tweet[key]])
        
    return classifications

# %%
# In[82]:

def load_data():
    data1 = load_data1()
    data2 = load_data2()
    data = {}
    for key in data1:
        data[key] = data1[key] + data2[key]
    return data

# %%
load_data2()
# Out:
# A Scottish greeting to #Trump from Robert Burns:  Some books are lies from end to end, And some great lies were never penn'd� #TrumpLies
# defaultdict(list,
#             {'Asks_for_Donation_Asks_you_to_buy_something_to_support_campaign': [['Again, @realDonaldTrump lies about his support for the Iraq war. #TrumpLies https://t.co/9TfLGKouLR',
#                'NA'],
#               ['"We trust American women."\r\rThank you, @TimKaine. #VPDebate',
#                'NA'],
#               ['Lets put ourselves in the shoes of young black &amp; Latino people who face the effects of systemic racism and feel their lives are disposable.',
#                'NA'],
#               ['RT @AndrewFinkNH: With Primary Day tomorrow Orlando is feeling some #marcomentum! Volunteers working hard for @marcorubio #TeamMarco https:',
#                'NA'],
#               ['to protect our LGBT citizens from the violence and oppression of a hateful foreign ideology. To protect us from terrorism,',
#                'NA'],
#               ['How dare he?! https://t.co/wTMzaHBSDh', 'NA'],
#               ['Donald Trump\'s "cavalier attitude about nuclear weapons is so deeply troubling. #DebateNight https://t.co/z66rUZz31J',
#                'NA'],
#               ['RT @JordanChariton: Here Debbie Wass Schultz says @BernieSanders Is Just Always getting "caught doing something wrong #DNCleak https://t.co',
#                'NA'],
#               ["ICYMI: @realDonaldTrump's FALSE claim that Saddam Hussein was 'so good' at 'killing terrorists'  https://t.co/2HsNuPSmY5 #TrumpLies",
#                'NA'],
#               ["RT @colincampbell: The New York Times legal team responds to Donald Trump's legal threat: https://t.co/pLxC6NoxfV",
#                'NA'],
#               ["Coming out often takes incredible courage. On #NationalComingOutDay, let's honor that courage by showing LGBT Ameri https://t.co/0CJwesashh",
#                'NA'],
#               ['NEW: Retired four-star General John Allen endorses @HillaryClinton https://t.co/ILc6B2oIs8',
#                'NA'],
#               ["RT @TheBriefing2016: In Indiana, Hillary Clinton is taking on the state's new, restrictive abortion law. https://t.co/SFMlDOlJfX",
#                'NA'],
#               ['RT @GenBoykin: #Faith is vital for our fighting men &amp; women and we must always protect their #religiousliberty. #military #ArmedForces #tco',
#                'NA'],
#               ["This election is too important to sit out. Go to https://t.co/tTgeqxNqYm and make sure you're registered. #NationalVoterRegistrationDay -H",
#                'NA'],
#               ['"I Saw #Trump\'s Tax Returns. You Should, Too." https://t.co/jUfpqZRdvJ',
#                'NA'],
#               ['RT @KellyAyotte: In a close race, YOUR VOTE could make the difference! #nhsen #nhpolitics #Election2016 #vote4kelly\r\rhttps://t.co/yGG6CJhre',
#                'NA'],
#               ["The Senate's highest ranking Republican calls on #Trump to release his tax returns: https://t.co/2xfqGV6e19",
#                'NA'],
#               ['We teach the technique of using OPM ... Other Peoples Money. Trump is a true con-man. https://t.co/4eQdT1svhr',
#                'NA'],
#               ['Griffin &amp; Sydney....still making Fatherhood cool after all these years!! https://t.co/QYW4TC3OJj',
#                'NA'],
#               ['RT @johnpodesta: We can fight climate change because our next president has a plan. @HillaryClinton #ImWithHer https://t.co/lazxsPm48W',
#                'NA'],
#               ['RT @OswaldRachel: .@RandPaul says privileged resolution disapproving of Saudi Arms sale will be introduced and voted on on Wednesday @CQnow',
#                'NA'],
#               ['RT @marceelias: Disappointed that split 6th Cir. (2-1) OVERTURNED restoration of Golden Week. Bad for voters. Bad for voting rights. https:',
#                'NA'],
#               ['Good decision. https://t.co/jgTq87ZxHw', 'NA'],
#               ['You have a choice. You decide. You deserve better. Because America deserves better. #RNCinCLE',
#                'NA'],
#               ['HRC is using the oldest play in the Dem playbook- when their policies fail, they are left w/this one tired argument!\rhttps://t.co/FNbCMmwLTn',
#                'NA'],
#               ['RT @jackhunter74: Senator @RandPaul to back bill blocking FBI hacking expansion https://t.co/IQRWJoZrpe via @Reuters',
#                'NA'],
#               ["Getting ready for Trump with Austin's finest. #godblesstexas https://t.co/0yZbcZpp0j",
#                'NA'],
#               ['A proven leader who shares our values." @AFLCIO\r\rWhy labor unions across industries are backing Hillary: https://t.co/y07F7uvqv3',
#                'NA'],
#               ['"If I were in charge, they would know...waterboarding is how we\'d baptize terrorists." Sarah Palin, Trump supporter https://t.co/IZamSzbE7q',
#                'NA'],
#               [".@realDonaldTrump says hell be the best for women.\r\rDon't think so. https://t.co/zsXgf8wQF2",
#                'NA'],
#               ['Ronald Reagan was elected Governor 50 years ago today! https://t.co/EgxXDZmFeN',
#                'NA'],
#               ['Trump may have (yet again) lied about donating to charity. https://t.co/Rzqa4x5FS9',
#                'NA'],
#               ["Crooked Hillary is bad. We can't let her take control of the White House. She will never make America great again!",
#                'NA'],
#               ['The Hyde Amendment restricts the reproductive rights of low-income womendisproportionately women of color. We need to repeal it now.',
#                'NA'],
#               ['"Hillary is not somebody who fears the future. She believes that it is ours to shape." @POTUS https://t.co/cSAdZFNa4G',
#                'NA'],
#               ["Hillary Clinton Had Gun Control Supporters Planted In Town Hall Audience' https://t.co/1GVq74iW8a",
#                'NA'],
#               ['We can shape government policy by supporting major ballot initiatives taking place in states throughout the country. https://t.co/DC0Q8HrKFI',
#                'NA'],
#               ['RT @IGNITE_National: Tell a girl to run - for office! #DeclareYourAmbition at https://t.co/Gcthrb8QwO https://t.co/AAIOYi1hFA',
#                'NA'],
#               ["RT @ByronYork: Mary Landrieu: 'I want to thank Mr. Trump for coming to LAI hope Sec Clinton will make her way down. I hope Pres Obama will",
#                'NA'],
#               ['.@realDonaldTrump doesnt pay his bills. https://t.co/Ro5iOKu4G9',
#                'NA'],
#               ['RT @jhseher: Up on #TheLead -- everything politics w/ @SaraMurray, @jeffzeleny, @mkhammer, @JoshuaGreen, @kayleighmcenany, @secupp + @JenGr',
#                'NA'],
#               ['Awkward: @realDonaldTrump invested in outsourcing companies he denounced on the campaign trail. #RNCinCLE https://t.co/giB84yV5z2',
#                'NA'],
#               ['RT @JuddLegum: Today in Trump:\r\r1. Attacked a fire marshal\r\r2. Said Hillary should be "locked up"\r\r3. Reminisced about his sexist attacks o',
#                'NA'],
#               ['RT @RepThomasMassie: Congress created the Federal Reserve, so it is Congresss responsibility to #AuditTheFed\r\rhttps://t.co/ajv5KEivaA',
#                'NA'],
#               ['A small business owner sold Donald Trump pianos for his Atlantic City casino.\r\rTrump stiffed him for the payment.\rhttps://t.co/9LMPenOZue',
#                'NA'],
#               ["Congrats to Flint, Michigan's @ClaressaShields on her second Olympic gold medal for @TeamUSA. https://t.co/u2RA7GoDiy",
#                'NA'],
#               ['Greetings from future leaders of America at @Georgetown Institute of Politics! @GUPolitics https://t.co/JaivMaepH3',
#                'NA'],
#               ['Our thoughts &amp; prayers are with the victims &amp; families of the Pulse Nightclub shooting in Orlando. #OrlandoUnited https://t.co/lInMkvYlXX',
#                'NA'],
#               ["As much as I think Obamacare's a mistake, just ignoring the debt to get to Obamacare is also a mistake. https://t.co/imAcw7wV6S",
#                'NA'],
#               ['@Cuckerella Get your FREE #CrookedHillary bumper sticker today! https://t.co/fPLtgFtGH7',
#                'NA'],
#               ['.@nytimes: the race to defeat Mr. Trump will continue to be exceedingly well funded. https://t.co/AxzHteR5R5',
#                'NA'],
#               ['RT @SuppliesOvrSeas: Thank you @RandPaul and @Alvarado4Senate for visiting SOS yesterday to learn more about our mission to Deliver a World',
#                'NA'],
#               ['Watch live: Hillary takes the stage for the first presidential debate  https://t.co/FbmDLQp03w #DebateNight',
#                'NA'],
#               ['RT @CatsRoundtable: CatsRoundtable listen live 9/11 9:00am EST AM970|https://t.co/pUM74zK5V6 \r@GovernorPataki - Friends in the Tower',
#                'NA'],
#               ['FACT CHECK: DONALD TRUMP WRONGFULLY CLAIMS THAT CLINTONS EMAIL SERVER WAS HACKED https://t.co/sVvqX4EcPL',
#                'NA'],
#               ['.@realDonaldTrump only cares about himself. https://t.co/5UByvTvJzY https://t.co/q8ApDeEFT5',
#                'NA'],
#               ['Time Is Running Out to Abolish Superdelegate Dominance https://t.co/BoPnYpPoy9',
#                'NA'],
#               ["More concerned Hillary Clinton couldn't seem to find Benghazi to send help 4 yrs ago than whether Gary Johnson knows where Aleppo is today.",
#                'NA'],
#               ['Looking forward to meeting with @SenBobCorker in a little while. We will be traveling to North Carolina together today.',
#                'NA'],
#               ['Will be speaking with @FoxNews in just a few minutes.', 'NA'],
#               ['Join the fight for a free internet: https://t.co/nJUL6vcmop https://t.co/xGPqRE1wLF',
#                'NA'],
#               ['Donald Trump said he has "great respect" for women. His actions and words say otherwise. https://t.co/DV0KszUZxM',
#                'NA'],
#               ["A blistering condemnation of the Obama admin's willful ignorance, in regards to the dangers of radical Islam: https://t.co/5AyIlvQOap",
#                'NA'],
#               ['"We have still have not shattered that highest and hardest glass ceiling. But some day, someone will." Hillary',
#                'NA'],
#               ["Let's beat back the assault on voting rightsa blast from the Jim Crow past that must be stopped.\r\rWe should expand voting rights instead.",
#                'NA'],
#               ['Jim Gray firmly supports coal-hating Hillary Clinton #StandWithRand #GoAwayGray @RandPaul https://t.co/dUj4YZ0RLa',
#                'NA'],
#               ['We need to fundamentally change the relationship between the U.S. Government and the Native American community.\rhttps://t.co/944F5JHtqV',
#                'NA'],
#               ['RT @brianhawkins25: @GovernorPerry makes impassioned plea for #criminaljusticereform @ALEC_states #ALECIndy https://t.co/Wa2LO35Oel',
#                'NA'],
#               ['Thank you all for your support! https://t.co/A0V3OlCqzg',
#                'NA'],
#               ['.@ddale8 @GreatAmericaPAC has been running ads for months! Here is an example #TrumpTrain @realdonaldtrump https://t.co/av7aTB9VKe',
#                'NA'],
#               ['Literally, there are thousands of people who die every single year because they cannot afford the medicine they need. Thats outrageous.',
#                'NA'],
#               ['@ShirlsAdams why are you with someone who lied to the American people? You should get on the #TrumpTrain! https://t.co/TC5gq32Atj',
#                'NA'],
#               ['.@HillaryClinton: Child care now costs more than rent. Heres how to fix this crisis. https://t.co/wKjkbDS8kH',
#                'NA'],
#               ["#Trump's hometown tax collector joins the chorus of people calling for him to release his tax returns: https://t.co/YF7vV4VFzx",
#                'NA'],
#               ['"We become stronger when black and white, Latino, Asian American, Native Americanall of usstand together. @BernieSanders',
#                'NA'],
#               ['TRUMP LIES ABOUT MINERS AND STEELWORKERS https://t.co/gOzhV97MvA #TrumpLies #RNCinCLE',
#                'NA'],
#               ['We need leadership in the @WhiteHouse!!! Only @realDonaldTrump can provide that!! Watch and RT!!! #TrumpTrain #MAGA https://t.co/0JlMcu4072',
#                'NA'],
#               ['RT @realDonaldTrump: Ready to lead. Ready to Make America Great Again. #Debate #MAGA',
#                'NA'],
#               ['#Trump in 2016: You can\'t have a country without borders.\rin 2013: We must "leave borders behind."\rWhich is it? https://t.co/EYTCfonf2B',
#                'NA'],
#               ['RT @nobarriers2016: "There is only one way we lose this election. If we don\'t turn out to vote." https://t.co/7KuswDiilb #StrongerTogether',
#                'NA'],
#               ['Taking on systemic racism and rebuilding trust and respect between law enforcement and the communities they serve will require all of us.',
#                'NA'],
#               ['RT @CR: Conservative Icon Given Prestigious Teaching Award at Ivy League School \rhttps://t.co/PJh9eeTb4Q\r@NateMadden_IV \r.',
#                'NA'],
#               ['Does this seem presidential to anyone? https://t.co/TEl2OPXj8A',
#                'NA'],
#               ['Court documents showed they could not determine whether some instructors even graduated high school. https://t.co/NIMukJhTKp',
#                'NA'],
#               ['#NateSilver Election Update: Democrats Should Panic  If The Polls Still Look Like This In A Week https://t.co/HnffRCkdc7',
#                'NA'],
#               ['RT @GovernorPataki: A great American. Rest in Peace Peter.  https://t.co/hX5ccIUBJM',
#                'NA'],
#               ['Funny how the entertainment industry hates blacklists, except when they target conservatives.',
#                'NA'],
#               ['RT @coloradodems: "Colorado, the choice could not be clearer"@MartinOMalley. Sing it proud Martin! https://t.co/WE1lrGQUjj https://t.co/is',
#                'NA'],
#               ['ICYMI: Graham questions @HCSInfo Charles Hucks about Horry County, SC Ransomware Attack.  https://t.co/VSyb8elLwl',
#                'NA'],
#               ["The only gae that atters each year atters even ore this year. Let's have a little fun before our Buckeyes battl https://t.co/tXYUsndRXF",
#                'NA'],
#               ['RT @glennbeck: Colorado Conservative Darryl Glenn Endorsed by Ted Cruz for U.S. Senate\rhttps://t.co/nOPKrV8oi7',
#                'NA'],
#               ['RT @realDonaldTrump: Mike Pence won big. We should all be proud of Mike!',
#                'NA'],
#               ["RT @TeamTrump: Mrs. Saucier's son is in prison for having classified info on an unsecured device. @HillaryClinton did FAR WORSE &amp; is runnin",
#                'NA'],
#               ['RT @TheRenodoc: Sen. Rand Paul endorses @Jen_Terhune in AD25  https://t.co/ZsFzoDEcKO  @RalstonReports @SteveSebelius @ChuckMuth @KRNV @KOL',
#                'NA'],
#               ['RT @igorvolsky: Paul Ryan must be feeling really good about himself tonight  https://t.co/CQHqa6dKu8',
#                'NA'],
#               ['.@HillaryClinton could transform early education in the United States (via @bi_politics) https://t.co/ft0ARVbTEa',
#                'NA'],
#               ['Further proof that they dont have the American peoples best interests at heart https://t.co/z0dAU6FISz',
#                'NA'],
#               ["ICYMI: My closing statement from last night's debate. https://t.co/nOVGVDmieC",
#                'NA'],
#               ['If Mr. Trump wanted to defend his tax practices, he could simply release his returns. He sure could. https://t.co/bO6iqyAWtL',
#                'NA'],
#               ['RT @CNN: Here are ways you can help the victims and their families after the #Orlando mass shooting https://t.co/a6bZY1kSNN https://t.co/mm',
#                'NA'],
#               ['RT @FaceTheNation: .@RandPaul: Trump understands that the Iraq war was a mistake. I want people that agree with him to run the state depart',
#                'NA'],
#               ['#NeverForget the brave men and women who died on 9/11 and those who still sacrifice to this day to protect and defend us.',
#                'NA'],
#               ['That time @mike_pence killed a preschool pilot program for apparently no reason: https://t.co/iDGHe4Eku3 #FBF',
#                'NA'],
#               ['The failing @nytimes talks about anonymous sources and meetings that never happened. Their reporting is fiction. The media protects Hillary!',
#                'NA'],
#               ['#News Trumps Blue Collar Base Wants More Jobs And An America Like The Past https://t.co/ZmOUoVw1Yb',
#                'NA'],
#               ['How the Press is Making the @ClintonFdn into the New Benghazi: https://t.co/7yctRz3JG6',
#                'NA'],
#               ['So much for that post-2012 @GOP autopsy, @Reince. https://t.co/jYir6AsexY',
#                'NA'],
#               ['"Wisconsin\'s attempt to tie food to jobs pays off"\rhttps://t.co/yaDhK3NN7j',
#                'NA'],
#               ['Ohio is stronger thanks to the dedication and service of our veterans.   Congratulations to this years Hall of Fam https://t.co/GnLdbD20Ij',
#                'NA'],
#               ["Thanks for the helpwe're doing our best to document every lie: https://t.co/5eFlPSizXQ @nytegan",
#                'NA'],
#               ['Dont miss out! Join them: https://t.co/3TKJ4H68Kz https://t.co/xT4ER9Dmrk',
#                'NA'],
#               ["Thank you, Christine. We're all standing by your side. https://t.co/7WimmvECqU",
#                'NA'],
#               ['"Middle-class families fighting to give your kids a better life: Democrats stand in your corner." @SenatorReid #DemsInPhilly',
#                'NA'],
#               ['RT @NBCNightlyNews: TONIGHT: @LesterHoltNBC presses Trump on evidence for Clinton server hack claim: "I will report back to you."\rhttps://t',
#                'NA'],
#               ['@FemalesForTrump you should join the #TrumpTrain. Sign up today! https://t.co/rpkYQB91Ru',
#                'NA'],
#               ['RT @HillaryClinton: "Let us declare again that we are a nation of interdependence and that in America, love always trumps hate." @CoryBook',
#                'NA'],
#               ["When millions of Americans are working longer hours for lower wages, we won't allow 57 percent of all new income to go to the top 1 percent.",
#                'NA'],
#               ['#Trump inherited a fortune and still managed to lose $916 million. https://t.co/XJylGKRjPY',
#                'NA'],
#               ['RT @JusticeWillett: Heroes all.\r\r Lorne Ahrens48\r Michael Krol40\r Michael J. Smith55\r Brent Thompson43\r Patrick Zamarripa32 https',
#                'NA'],
#               ['Why It Takes Two Years for\rSyrian Refugees to Enter the U.S. https://t.co/ETaWUBrkql @realDonaldTrump',
#                'NA'],
#               ['After a day of #dwts filming @ the Fayette Co Fair some Back Porch BBQ hits the spot! https://t.co/riCN6SP0P3',
#                'NA'],
#               ['Inside Bill Clinton Inc.: Hacked memo reveals intersection of charity and personal income. #DrainTheSwamp!\rhttps://t.co/UfDVzeSDfd',
#                'NA'],
#               ['"I did not email any classified material." https://t.co/KWlc9Qh6lY #Clinton Vs. #FBI https://t.co/0rSfi5ipTs',
#                'NA'],
#               ["RT @realDonaldTrump: Obama's disastrous judgment gave us ISIS, rise of Iran, and the worst economic numbers since the Great Depression!",
#                'NA'],
#               ["I say to Donald Trump: instead of giving speeches about trade why don't you lead by example and make your goods in America. #debatenight",
#                'NA'],
#               ['Heading to New Hampshire - will be talking about Hillary saying her brain SHORT CIRCUITED, and other things!',
#                'NA'],
#               ['RT @marklevinshow: Thank you, Ted Cruz. And thanks to all who supported and voted for him. https://t.co/DwnzxEP74P',
#                'NA'],
#               ['U.S. Senator Rand Paul plans to introduce new amendment to get rid of Selective Service https://t.co/Mmoza0yZWR @RandPaul #StandWithRand',
#                'NA'],
#               ['How long did it take your staff of 823 people to think that up--and where are your 33,000 emails that you deleted? https://t.co/gECLNtQizQ',
#                'NA'],
#               ['RT @timkaine: A person who trash talks our own military should never set foot in the Oval Office. https://t.co/h04p4QF1xz',
#                'NA'],
#               ['Trump was a bully at that time, just as he is now. https://t.co/qDk1ZHcWmN',
#                'NA'],
#               ['RT @HillaryClinton: Thank you, California! https://t.co/EgtQpT6JZT',
#                'NA'],
#               ['This race is winnable if voters know Feingold voted for Obamacare, broke promises: "Poll finds Johnson up 5..." https://t.co/GJvIhsPlWV',
#                'NA'],
#               ['If the Republican Convention had blown up with e-mails, resignation of boss and the beat down of a big player. (Bernie), media would go wild',
#                'NA'],
#               ['RT @rose10052: Orlando stands with @marcorubio!\r#SuperSaturday #Marcomentum #Finishstrong https://t.co/zkf0FtBriT',
#                'NA'],
#               ['RT @NASA_Johnson: Johnson Space Center management welcome home #AstroKate: JSC Center Director Ellen Ochoa; and Astronaut Office Chief Chri',
#                'NA'],
#               ['Who are you voting for President?? RT TO SPREAD THE WORD!! Polls need to be fair To Trump!!!',
#                'NA'],
#               ['Enjoyed joining @mitchellreports this afternoon from #RNCinCLE on @MSNBC https://t.co/JzFeWmKeH4',
#                'NA'],
#               ['We need @HillaryClintons leadership -- not @realDonaldTrumps angry &amp; divisive rhetoric. https://t.co/xm71ftuQZJ',
#                'NA'],
#               ['Big win tonight for @ToddYoungIN - A critical seat for the GOP to hold! #ElectionDay',
#                'NA'],
#               ['RT @kelseyc00per: NEW @RandPaul WEB AD highlighting his record of always standing for KY by defending KYans liberties &amp; rights. https://t.c',
#                'NA'],
#               ['Reality Check: a vote for anyone other than @realDonaldTrump in a battleground state like WI might as well be a vot https://t.co/3csMHYfV4H',
#                'NA'],
#               ['Speaking at Mercedes Benz in North Charleston.  WATCH: https://t.co/TSfHsgrl0F',
#                'NA'],
#               ["Snapchat's 7 Brand Partners for the Summer Olympics https://t.co/tYyo4NOPMN",
#                'NA'],
#               ['After criticizing Clinton for not holding news conferences, Trump held none himself. What a hypocrite. https://t.co/HoIL66Q0xJ',
#                'NA'],
#               ['Maybe, just maybe, something is wrong when we have the highest rate of childhood poverty of nearly any major country on earth.',
#                'NA'],
#               ["If you've had enough of Washingtons brokenness, wastefulness, empty promises &amp; arrogance, join us.  #RNCinCLE",
#                'NA'],
#               ['With the 1995 tax info, a core truth about #Trump was confirmed: He is not a master builder. https://t.co/EHgcxtJeBb',
#                'NA'],
#               ['@BarackObama you have at least $175 million you can spend on #Zika right now.Why are you holding back? https://t.co/2Juu2XEcdz',
#                'NA'],
#               ['.@TheHill: Donald Trump declared Thursday that "you have to be wealthy in order to be great." https://t.co/MPRliRwzo7',
#                'NA'],
#               ["But Hillary Clinton's legacy does not have to be America's legacy. The problems we face now - poverty and violence at home,",
#                'NA'],
#               ['.@nydailynews: Trump is neither a man of ideas nor a man of character. https://t.co/jQxZL20GYX',
#                'NA'],
#               ['For years, Trump has been taking from American taxpayers with both hands and giving nothing back. https://t.co/Xbu9LkD89T',
#                'NA'],
#               ['The media is at it again... https://t.co/CphtcRBVMc', 'NA'],
#               ["Proud to support @richtaylorIA for re-election to the Iowa State Senate. He's a principled, courageous leader in Io https://t.co/bDf47jQdIO",
#                'NA'],
#               ['Fix trade. Stop manufacturing Trump clothing in Mexico. #RNCwithBernie',
#                'NA'],
#               ['TODAY WE MAKE AMERICA GREAT AGAIN!', 'NA'],
#               ['At 6:00 pm, Ill kick off 2016 Godkin Lecture at the @JFKJrForum for a discussion on economic mobility. Watch live: https://t.co/08z7piryMD',
#                'NA'],
#               ['RT @joshrogin: Pence is right. Clinton &amp; Obama tried to negotiate an Iraq troop extension but failed. Bush admin always anticipated such an',
#                'NA'],
#               ['RT @HillaryClinton: How can we prevent the spread of Zika in the U.S.? Hillary and @TimKaine respond on @Quora: https://t.co/ncuMmTCrSN htt',
#                'NA'],
#               ['A top Clinton Foundation official said he could name 500 different examples of conflicts of interest. \rhttps://t.co/rtWhdYOyq7',
#                'NA'],
#               ['Scheduled to speak with @CNN in just a few minutes.  Hope you tune in.',
#                'NA'],
#               ['RT @russfeingold: Join Russ and @BernieSanders for an exciting event in Madison TOMORROW! \r\rRSVP here: https://t.co/DuI73Zk2Pt https://t.co',
#                'NA'],
#               ['#NateSilver What Could The Polls Be Missing? - In this weeks politics chat, we weighed reasons the polls could... https://t.co/jYs4ROQ1bx',
#                'NA'],
#               ['RT @vrobinson: For those of you who want socialism in America. https://t.co/T9HgFj8oEO',
#                'NA'],
#               ["Very concerned about the outage in Puerto Rico and the millions of families who don't have power. Hoping it's resto https://t.co/Y2oG1CS2AN",
#                'NA'],
#               ['News Update: How to Counter Chinas Global Propaganda Offensive https://t.co/xE44gXJAXZ',
#                'NA'],
#               ["If Mr. Trump is serious about standing up for working families, he won't throw 20 million working people off of health insurance.",
#                'NA'],
#               ['RT @weeklystandard: "I have never seen [@tedcruz] waver from the fight that he has in front of him, or from his convictions." Carly https:',
#                'NA'],
#               ["I'm encouraged by these comments by President-elect @realDonaldTrump. https://t.co/iMUfIR3nHM",
#                'NA'],
#               ['Wonder if Trump thinks this makes him smart. https://t.co/D8U9EYemYD',
#                'NA'],
#               ["It's great to be in Nevada today urging Republicans to GOTV for @Heck4Nevada! https://t.co/xfTaHiBrKV",
#                'NA'],
#               ['The Foundation for Excellence in Education is excited to kick off our 9th annual National Summit on Education Refor https://t.co/o6i1IwGNDb',
#                'NA'],
#               ["Maine #Dems voted to Abolish #superdelegates. The #DNC ain't happy. They're fighting back. #FeelTheBern https://t.co/pq0nk6Pp9R",
#                'NA'],
#               ['On so many issues, #Trump says it, but @mike_pence has actually done it. https://t.co/irl9M9t7YD',
#                'NA'],
#               ['"Our responsibility as citizens is to keep doing our part to build that better, stronger, fairer America we seek. And I know you will.',
#                'NA'],
#               ['RT @Heritage: Over 20,642 new regulations have been added since the beginning of the Obama presidency. https://t.co/LFLLb9JIi9',
#                'NA'],
#               ['@RepMickMulvaney would be a great choice for OMB Director. https://t.co/8n0y7SnkCu',
#                'NA'],
#               ['RT @realDonaldTrump: Leaked e-mails of DNC show plans to destroy Bernie Sanders. Mock his heritage and much more. On-line from Wikileakes,',
#                'NA'],
#               ['#TBT to Bernie talking about the political revolution and giving power back to the average American in 1990.\rhttps://t.co/NxUZBPihsN',
#                'NA'],
#               ["RT @startelegram: . @tedcruz: Senate in danger, Texas GOP can't stay home https://t.co/6Ax2j8se8b https://t.co/pAqpOLNih5",
#                'NA'],
#               ['Nuestros hroes y nuestras familias merecen mucho mejor que las polticas divisivas @ de realDonaldTrump.\rhttps://t.co/mvfdAZWyuo',
#                'NA'],
#               ['Will there be one word about student debt or making college affordable? Or just concerned about more tax breaks for the rich? #RNCwithBernie',
#                'NA'],
#               ["Over and over the government has broken its promise to respect Native American sovereign rights. Now it's time for real change. #NoDAPL",
#                'NA'],
#               ['RT @TeamTrump: .@HillaryClinton had her chance and she BLEW IT. #BigLeagueTruth #Debates https://t.co/d2MI0DCg5Y',
#                'NA'],
#               ['@mike_pence Comprehensive immigration reform aka open borders amnesty. ICE union is the deportation force. #VPDebate',
#                'NA'],
#               ['If Trump wants to make America great again, he should start by buying American steel for his construction projects.',
#                'NA'],
#               ['RT @HFA: No matter who you supported in the primary, we are united and stronger together. #DemsInPhilly https://t.co/C3Ynm21jKo',
#                'NA'],
#               ['As for me, I absolutely will NOT support Hillary Clinton for President. (2)',
#                'NA'],
#               ['RT @BrianKelsey: "Brian Kelsey is the type of leader who will stand up for our Christian values and the unborn." -@RickSantorum https://t.c',
#                'NA'],
#               ['RT @RandPaul: Read the stories of everyday Americans badgered and harassed by their own government: https://t.co/4FwB2o6SpG https://t.co/EP',
#                'NA'],
#               ['Were excited to announce that @jeffsnation, President of JIJ Communications, is joining our strategic team. https://t.co/d9N3BpTELm',
#                'NA'],
#               ["RT @SopanDeb: Gingrich saying Clinton doesn't hold pressers. She has taken questions 6 times in 3 weeks. Trump hasn't held presser since Ju",
#                'NA'],
#               ['RT @TheBriefing2016: He opposes raising the minimum wage, and he really, really, really wants to privatize Social Security. https://t.co/hc',
#                'NA'],
#               ['Live NOW: Gov. John Kasich speaking to the Greater Cleveland Partnership Annual Meeting @GCPartnership https://t.co/LGcg9pVJAV',
#                'NA'],
#               ['"To be great, we can\'t be small. We have to be as big as the values that define America." Hillary https://t.co/RPCgLUrBTs',
#                'NA'],
#               ['@ChristinaD23 @aitanaraguan @catsdailytruth1 @Bernie_Sanders_ @BernieTweet2016 @USMCLiberal @ArabsForBernie @VoteBernie4Pres @RebeccaIngham',
#                'NA'],
#               ['.@Koch_Industries Our great nation can no longer be hijacked by right-wing billionaires like the Koch brothers. https://t.co/svvNE1gdJE',
#                'NA'],
#               ["RT @TheBriefing2016: Endorsement -- noun -- 1.\ran act of giving one's public approval or support to someone or something.\r\rhttps://t.co/R",
#                'NA'],
#               ['Visited Fort Jackson earlier today. Truly appreciate all these brave men and women do in protecting our nation. https://t.co/G2aFxpvztQ',
#                'NA'],
#               ['RT @SenGillibrand: Love this.\r\r"@HillaryClinton has spent her life fighting for childrenhere are 8 ways shes changed their lives." \r\rhttp',
#                'NA'],
#               ['Mentiroso", "fraude", xenfobo" y otras cosas que lderes republicanos dicen sobre Trump. https://t.co/QnPOgws3F7',
#                'NA'],
#               ['My prayers and condolences to the victims and families of the terrible tragedy in Nice, France. We are with you in every way!',
#                'NA'],
#               ["Don't forget to set your clocks tonight. https://t.co/8v43LESX0i",
#                'NA'],
#               ['"Two years ago, my son was killed by a mass shooter. Ive never spoken about it publicly until now." Caryn Michaels https://t.co/2GrJCLXhmW',
#                'NA'],
#               ['RT @runforthehouse: @GreatAmericaPAC PLEASE PLAY THIS ON MAJOR MEDIA OUTLETS. Especially in Eastern Pennsylvania (3rd largest). https://t.c',
#                'NA'],
#               ["Let's do this. #DebateNight https://t.co/NkPEGHzucT", 'NA'],
#               ['.@nytimes Ed Board: Why @realDonaldTrump Should Not Be President https://t.co/6AhfqtZMMd',
#                'NA'],
#               ['RT @Jamie_Weinstein: Compare the ledes for the NYTimes obits of Castro and Pinochet: https://t.co/eUADJbYJnO',
#                'NA'],
#               ['#News Why our government representation should look more like us https://t.co/GCpP2KYYeq',
#                'NA'],
#               ["RT @TheBriefing2016: Why hasn't @realDonaldTrump released his tax returns? Looks like he's out of excuses.\rhttps://t.co/6SbJdlPWFD",
#                'NA'],
#               ['We now have confirmation as to one reason Crooked H wanted to be sure that nobody saw her e-mails - PAY-FOR-PLAY. How can she run for Pres.',
#                'NA'],
#               ['The reality is that today millions of our fellow Americans are working at starvation wages.',
#                'NA'],
#               ['"You can leave this ad mutedthere\'s nothing to hear." @NyleDiMarco\r\rhttps://t.co/tTgeqxNqYm https://t.co/QOqcWnw7OJ',
#                'NA'],
#               ['Join Hillary on the trail in North Carolina with @BernieSanders and @Pharrell. https://t.co/ffvKpYDAe7\r\rhttps://t.co/3TKJ4H68Kz',
#                'NA'],
#               ['I will be damned if we let the Republican Party win the working class.\rhttps://t.co/PYVLkmbizl',
#                'NA'],
#               ['Priorities is excited to be kicking off the first of our digital ads today. Click here to find out the details: https://t.co/7nk9qQSdPE',
#                'NA'],
#               ['A great morning w/ @OhioGOP Delegates. @MaryTaylorOH &amp; @RobPortman know what it takes to keep OH strong. #RNCinCLE https://t.co/ETQmqfwFvd',
#                'NA'],
#               ["It's a miracle a nuclear weapon hasn't been used in war since 1945. Congress can't allow the Tweeter in Chief to st https://t.co/M9NALQCsQz",
#                'NA'],
#               ['God bless Saint Teresa and God bless the Sisters of the Poor. https://t.co/rxKXqmdVPH',
#                'NA'],
#               ['WikiLeaks reveals Clinton camps work with VERY friendly and malleable reporters \r#DrainTheSwamp #CrookedHillary\rhttps://t.co/bcYLslrxi0',
#                'NA'],
#               ['You dont make America great again by insulting everyone you come across, @realDonaldTrump.\rhttps://t.co/ZE7azatIBB',
#                'NA'],
#               ['"Education should lift you up, not hold you back. Were going to help you pay back and pay down your loans." https://t.co/VkVm51nWIY',
#                'NA'],
#               ['Mike Pence and Donald Trump may want to take us back to a different century, but we wont let that happen. https://t.co/4ml4Xk8GvK',
#                'NA'],
#               ['String of deadly blasts in Baghdad part of ISIS effort to force troops to come back from front lines to protect city https://t.co/VPGVXPAlPS',
#                'NA'],
#               ['RT @jaredsmall: Still grinding it out here at the office. Cause @marcorubio is major \r#everyminutecounts #marcomentum https://t.co/kswG4',
#                'NA'],
#               ['"Quiero que t ayudes a elegirla nuestra prxima Presidenta de los Estados UnidosObama. https://t.co/afIzmJR7Jp',
#                'NA'],
#               ['She made history. #StrongerTogether https://t.co/tg3S1iaI0x',
#                'NA'],
#               ['Remember that time #Trump was in Europe for one of its "most important days" and he talked...golf?\rhttps://t.co/PFPLftTmca',
#                'NA'],
#               ['In Florida only 2 legitimate candidates on ballot in Nov. I wont vote for Clinton &amp; I after years of asking people to vote I wont abstain.',
#                'NA'],
#               ['One year ago #SCOTUS made history. But there is more work to do. #OTD #ImWithHer https://t.co/POqodZ323S',
#                'NA'],
#               ['.@HillaryClinton laid out sound plans on raising the #minimumwage, middle class tax breaks &amp; debt-free college: https://t.co/U2hkujTLGJ',
#                'NA'],
#               ['RT @HFA: RT if you agree: Every student should learn computer science. https://t.co/IzFbWB4I1I',
#                'NA'],
#               ['There is one candidate running for president who has pledged to raise the minimum wage to a living wage. That is @HillaryClinton.',
#                'NA'],
#               ['Have you seen our new ads with @whenwomenvote? Check them out here: https://t.co/bHqZABmCy2',
#                'NA'],
#               ["RT @DavidFBowen: RSVP to hear Bernie's live video address tomorrow: https://t.co/d3otYjXSIr &gt;Goal always must be something bigger than your",
#                'NA'],
#               ['Goofy Senator Elizabeth Warren @elizabethforma has done less in the U.S. Senate than practically any other senator. All talk, no action!',
#                'NA'],
#               ["Tonette &amp; I went to the wedding of her cousin's daughter &amp; new son-in-law: Stephanie &amp; Zachary Kundinger.",
#                'NA'],
#               ['Great effort by the @TedCruz campaign to offer Republicans an alternative to Donald Trump and fight for conservatism.',
#                'NA'],
#               ["RT @SteeleShippy: Packed house 100+ in St Joe today for @JayAshcroftMO's Show-Me #VoterID Rally w/ @GovMikeHuckabee! #Momentum https://t.co",
#                'NA'],
#               ['With a record as terrible as his, would you trust @realDonaldTrump with our economy?\rhttps://t.co/UJPpo59WJC',
#                'NA'],
#               ['https://t.co/NTJH00Y8gz', 'NA'],
#               ['The @nytimes Has Exposed Yet Another Shady For-Profit Trump School Called "Trump Institute." https://t.co/m26wxbNeFT',
#                'NA'],
#               ['Congrats to GB Packers even though I hoped #DallasCowboys would come thru.  Tough loss for us but Packers are great team with great fans.',
#                'NA'],
#               ["RT @HillaryClinton: This Oakland entrepreneur is doing more than running a small businesshe's changing lives.\rhttps://t.co/2g47l5hjDX",
#                'NA'],
#               ['Early voting has started! Avoid the lines on Election Day and cast your ballot before November 8th: https://t.co/EGghNrgkDK',
#                'NA'],
#               ['Whenever you hear Trump talk about foreign policy, picture him in the Situation Room making decisions for all of us. https://t.co/7QBVFziTdN',
#                'NA'],
#               ['Went down the slide @WIStateFair with my niece Isabella. https://t.co/xC4eBNMFKc',
#                'NA'],
#               ["RT @HillaryforVA: Virginians have known and loved @timkaine for decadesand we're proud to have him on Team Hillary: https://t.co/JkfxE6jfUX",
#                'NA'],
#               ['@MrsParkington .@RealDonaldTrump will #MAGA WATCH https://t.co/eLZy3J4y0G',
#                'NA'],
#               ['Happy birthday, @SpeakerVos!', 'NA'],
#               ['Gov. John Kasich statement on the attacks in #Munich https://t.co/RAB83cfXjL',
#                'NA'],
#               ['Question: "Do you think Donald Trump is qualified to be president?"\r\r"No, I do not." Hillary\rhttps://t.co/04viDc5G7t',
#                'NA'],
#               ['RT @DannyEFreeman: These Wikileak emails are actually pretty extraordinary. Search and give a read. #DNCleak \rhttps://t.co/xQFumqHV4B\rhttps',
#                'NA'],
#               ['.@LATimes: Trump &amp; his surrogates are engaged in a smear campaign reminiscent of the dark days of McCarthyism. https://t.co/M0dYFxWPUk',
#                'NA'],
#               ['The energy were seeing out there isnt just about what were againstits about what were for: a future in which everyone counts.',
#                'NA'],
#               ['"Everyone here...has stumbled on their own stony roads. Its grace that lifts us up, grace that leads us home. Hillary to the @nbcusa_inc',
#                'NA'],
#               ['ICYMI: What value is there in the #Trump name? For his casinos, not enough. https://t.co/jVt48rT09K',
#                'NA'],
#               ['RT @timkaine: "Republican senators...once they\'ve made sure nobody is listening, will tell you how fantastic a senator that Hillary Clinton',
#                'NA'],
#               ["RT @ryangrim: The guy speaking right now is literally on Putin's payroll. https://t.co/oyMv4bENLp",
#                'NA'],
#               ['RT @CapehartJ: Reason 5 for Tim Kaine: Stability. https://t.co/mTmXrdddwT',
#                'NA'],
#               ['@Shizlord69 why are you with someone who lied to the American people? You should get on the #TrumpTrain! https://t.co/TC5gq32Atj',
#                'NA'],
#               ['So many self-righteous hypocrites. Watch their poll numbers - and elections - go down!',
#                'NA'],
#               ['RT @EMPIREREPORTNY: NEW YORK PARENTS DEMAND GREAT SCHOOLS... https://t.co/Ufn2AnqdeU https://t.co/riOkUuBmiE',
#                'NA'],
#               ["American pharmaceutical companies couple outrageous prices on drugs with new and inventive ways to avoid paying taxes. It's truly shameless.",
#                'NA'],
#               ['Laura Ingraham practices Trump-level dishonesty. https://t.co/DTXhVzmrFU',
#                'NA'],
#               ['#News VAT of Deplorables - Trump picks terrible advisers, too. https://t.co/2j3GDS0Brv',
#                'NA'],
#               ['We have a Bill of Rights and we have a Constitution. We must defend them without exception. https://t.co/5r0SplznUA',
#                'NA'],
#               ['#News Election Update: Trumps Best Chance To Win In Obama Territory Is In Maine https://t.co/iMIVfumAsM',
#                'NA'],
#               ["RT @ddlovato: The election is just weeks away. Check if you're registered to vote at https://t.co/HcMAh8ljR0, only takes a few clicks! http",
#                'NA'],
#               ['Great to see so many businesses looking to expand in our state and provide new job opportunities. https://t.co/eM9GhinMMf',
#                'NA'],
#               ["Why should we trust @realDonaldTrump to run the nation's business?\r\rWe shouldn't.\rWATCH: https://t.co/H4MX6Sf6KG",
#                'NA'],
#               ['RT @Kredo0: .@SenTedCruz to Americans: Take off the blinders and call the enemy what it is: radical Islamic terrorism https://t.co/OXnJax',
#                'NA'],
#               ['LA Times- USC Dornsife Sunday Poll: Donald Trump Retains 2 Point Lead Over Hillary:\rhttps://t.co/n05rul4Ycw',
#                'NA'],
#               ['Together for America Launches for Republicans and Independents Backing @HillaryClinton: https://t.co/AsaKJgkZtW #StrongerTogether',
#                'NA'],
#               ['I have met people in every state who have hope in their eyes and are prepared to come together to transform our cou https://t.co/dSdw5MMPTI',
#                'NA'],
#               ['"President Trump" is a dangerous proposition.\r\rMitt Romney, Ted Cruz, and Marco Rubio agree.\rhttps://t.co/fUkISvgaXC',
#                'NA'],
#               ["A review of @FEC filings shows #Trump's companies are profiting off his campaign  bigly. https://t.co/LWg367R0DF",
#                'NA'],
#               ['Not every wound can be seen. Our veterans deserve the best mental health services we can give. #NBCNewsForum https://t.co/vHoPy09BvC',
#                'NA'],
#               ['RT @dcexaminer: Ted Cruz blasts FBI\'s "James Comey \'friends and family\' cover-up" in tweet about #ProjectVeritas video https://t.co/F48pT3Y',
#                'NA'],
#               ['RT @NewsGuyGreg: 1:1 with @RealBenCarson - Getting his take on the conventions and where the campaigns go from here. @CBS12 https://t.co/KS',
#                'NA'],
#               ['Young people face tough challenges, but they have the ability to do something about it: Vote. https://t.co/dm98k71nf1',
#                'NA'],
#               ['Show your support for Donald Trump! Sign the petition today! https://t.co/teTzwyrERF https://t.co/vEMlYVY0EA',
#                'NA'],
#               ['Bernie should pull his endorsement of Crooked Hillary after she decieved him and then attacked him and his supporters.',
#                'NA'],
#               ['RT @RandPaul: #TBT to last week when the GOP beat the Dems in congressional baseball game! All proceeds go to charity @BGCA_Clubs https://t',
#                'NA'],
#               [".@HillaryClinton's plan would create good-paying jobs today and drive up wages in the future. https://t.co/lkwa5fBRX5 #InfrastructureMatters",
#                'NA'],
#               ['RT @cspan: Sen. @RandPaul: "Our first order of business will be a #budget that never balances. A budget that adds $9.7 trillion to the debt',
#                'NA'],
#               ["There's nothing presidential or admirable about the way @realDonaldTrump speaks about women. #Debate",
#                'NA'],
#               ['I agree Mike - thank you to all of our law enforcement officers! #VPDebate \r\r"Police officers are the best of us..."\r@Mike_Pence',
#                'NA'],
#               ['The safety of our kids is more important than the interests of the NRA. Our leaders should act like it. https://t.co/Rg3OcMf1Mc',
#                'NA'],
#               ['RT @HillaryClinton: Women have the power to stop Trump.\r\rhttps://t.co/tTgeqy51PU\rhttps://t.co/VH3woeAf9Q https://t.co/NjvbkPsjPR',
#                'NA'],
#               ['Hoping more communities can partner with us for more effective and less costly management of non-violent offenders.  https://t.co/Ei2pDm2woT',
#                'NA'],
#               ['Good to know he believes in extreme vetting for immigrants but not when it comes to the people he hires. https://t.co/zRotPsnmAc',
#                'NA'],
#               ['These new inductees into Ohios Veterans Hall of Fame exemplify distinguished service &amp; dedication! Thanks for all https://t.co/RRPzb9fAuA',
#                'NA'],
#               ['Great start to #NRAAM! Met with some supporters and guns lovers this morning for a private Q&amp;A and photos. https://t.co/3nWYr0SXY2',
#                'NA'],
#               ['Maybe, just maybe, we want to pass legislation to make the wealthy start paying their fair share in taxes before we start slashing Medicare.',
#                'NA'],
#               ["Last week @realDonaldTrump and I agreed to push for this. Good to see GOP leader join. Let's replace &amp; repeal NOW https://t.co/1TgBDyPJId",
#                'NA'],
#               ['"A tsunami is coming." #RNCinCLE https://t.co/accElNOo83',
#                'NA'],
#               ['In 2011, Hillary advised @POTUS on the mission to take out bin Laden. Trump was on the Apprentice. https://t.co/PzwYD5OoXu',
#                'NA'],
#               ['RT @HillaryClinton: Some fights are too important to stay silent. Preventing gun violence is one of them. Stand strong @ChrisMurphyCT. http',
#                'NA'],
#               ['hen my father says he will make America great again, he will deliver -- Ivanka #RNCinCLE #gopconvention',
#                'NA'],
#               ['"@AprilLaJune: OREGON votes today! Go vote for @realDonaldTrump and kick it BIG TIME! https://t.co/SLYwyM8w1D"',
#                'NA'],
#               ['Definitely not helping your candidates image as a sexist. https://t.co/AhDRLvIysy',
#                'NA'],
#               ["It's Election Day, Ohio! Polls are open 6:30AM - 7:30PM - Find your polling location here: https://t.co/ZJy7IKFEBj",
#                'NA'],
#               ['As secretary of state, Hillary restored our reputation around the world and made us safer. https://t.co/K5xvmKOAm7',
#                'NA'],
# ...
#                '-1'],
#               ["RT @nobarriers2016: .@HillaryClinton's commitment to foster cares system lives on through DNC speaker, Jelani Freeman. #StrongerTogether ht",
#                '1'],
#               [".@realDonaldTrump wants you to forget everything he's said.\rDon't.\rhttps://t.co/IOHqUoUNFO",
#                '-1'],
#               ['RT @JonahNRO: Can you help the last 7 survivors of the USS Arizona return to Pearl Harbor for their final salute? https://t.co/SW9m0hXsbj',
#                '0'],
#               ['.@motherjones: Former models for Donald Trumps agency say they violated immigration rules and worked illegally https://t.co/7ib0TPz54D',
#                '-1'],
#               ['.@SenJohnBarrasso attempts unity. #gopconvention https://t.co/tPORjrsZjE',
#                '-1'],
#               ['Happy first day of summer. https://t.co/yfuIRFr6mG', '1'],
#               ['Today we reached a good bipartisan agreement on Zika funding in Senate. Thank you to @RoyBlunt for your efforts. https://t.co/shKYjsg6zF',
#                '1'],
#               ['Weve got to say with one voice that Latinos are a vital part of the American community.\rhttps://t.co/IfxluhqpKQ',
#                '0'],
#               ['What a hypocrite. https://t.co/epB4nUJ3zt', '-1'],
#               ['Only 71 left! Hurry and save $10 on the Art of Politics tote here: https://t.co/28PCWA4QVZ https://t.co/iV1OowtWAe',
#                '1'],
#               ['#TrumpLies https://t.co/hkRiicXHvU https://t.co/zhaSiPdkvT',
#                '-1'],
#               ['"This is a time to stand together and resolve to do everything we can to defend our communities and country." Hillary on the attack in FL',
#                '0'],
#               ['First #WorldSeries win for the @Cubs since my mom was 6 years old. #MLB https://t.co/Cf2ur21WIg',
#                '1'],
#               ["RT @damon_thayer: There's @PrattforKY listening to @RandPaul address health care issues right now at Georgetown Community Hospital. https:/",
#                '1'],
#               ['Economists project that Trumps plans would add more than $5,000,000,000,000 to the national debt. That\'s "trillion" with a "T."',
#                '-1'],
#               ['We have got to tell corporate America that if they want us to buy their products, they damn well better manufacture them in America.',
#                '-1'],
#               ['This is why we cannot afford to lose the Senate. https://t.co/IglWv5CC0R',
#                '0'],
#               ['The media refuses to talk about the three new national polls that have me in first place. Biggest crowds ever - watch what happens!',
#                '-1'],
#               ['@trumpsquatch help @realDonaldTrump #BuildTheWall https://t.co/hgBen5kCWz',
#                '1'],
#               ['#StandWithRand https://t.co/c3ZduxRzyC', '1'],
#               ['How dare @realDonaldTrump question the strength of combat Veterans who come home with scars of war (1/2)',
#                '-1'],
#               ['RT @RepHughes: I am proud to join these leaders as well as @GregAbbott_TX, @tedcruz, @NRA, @TXRightToLife, and @txoga in supporting @Christ',
#                '1'],
#               ['RT @nobarriers2016: Shattering glass ceilings. Breaking barriers. #WeMadeHistory! #StrongerTogether #DemsInPhilly https://t.co/subunheqAE',
#                '1'],
#               ['In a volatile world, the last thing we need is a volatile president. WATCH: https://t.co/L88b9VDSOZ',
#                '-1'],
#               ['A headline 227 years in the making. https://t.co/7RDeQ3bQ3z https://t.co/IuHMa3tUTr',
#                '1'],
#               ['Trump talks a lot about our trade policies and outsourcing American jobs but his own clothing line is made in Bangladesh, Mexico and China.',
#                '-1'],
#               ['Did you hear? We launched our #StopTrump campaign today. Read about it here!  https://t.co/9ygH4Vt5bW',
#                '-1'],
#               ['Pleased to sign 12 bills into law that will continue to strengthen Ohio. https://t.co/k2eQ7bzblN',
#                '1'],
#               ['Our progress is on the ballot.\rTolerance is on the ballot.\rDemocracy is on the ballot.\r\rMake a plan to vote: https://t.co/ywyzFUKNZi',
#                '1'],
#               ['Sen. @RandPaul Calls on HHS to Follow Senate Lead in Increasing Access to Opioid Addiction Treatment https://t.co/ii6jz69cls #StandWithRand',
#                '0'],
#               ["https://t.co/Br1MVBduil one of the cooler things I've seen in a while.  Texas made of course!! https://t.co/yC3tbinsOI",
#                '1'],
#               ["RT to let @TimKaine know you've got his back tonight. #VPDebate https://t.co/XzjUE0cfnp",
#                '1'],
#               ['RT @ADHRB: .@RandPaul people are starving in #Yemen so we need to debate about the #WarInYemen. #StopArmingSaudi',
#                '0'],
#               ['No one person alone can address the enormous problems facing working families in America. It will take a movement of millions of people.',
#                '0'],
#               ['@txcelat help @realDonaldTrump #BuildTheWall https://t.co/hgBen5CdO7',
#                '1'],
#               ['It is a national disgrace that billionaires are able to heavily influence the political process by making huge contributions.',
#                '-1'],
#               ['#News Clinton Probably Finished Off Trump Last Night - Im not sure I need to tell you this, but Hillary Clinto... https://t.co/YAh372Xg2y',
#                '-1'],
#               ['After the Orlando attack, @realDonaldTrump suggests President Obama let it happen: https://t.co/8CqS7BKsA3',
#                '-1'],
#               ['RT @EmilyMiller: Iran Cash: GOP Senate Wants to Aid Israel Self Defense - Watch my @OANN report @LindseyGrahamSC @tedcruz  https://t.co/Qp0',
#                '-1'],
#               ["RT @nobarriers2016: .@timkaine was a great mayor, governor and senator. Next he'll be a great VP! #VPDebate https://t.co/QeUjMflxpr",
#                '1'],
#               ['Great news as Oklahoma has joined the movement for a fed balanced budget amendment. Our 29th state! https://t.co/VPA7nttiju',
#                '1'],
#               ['RT @HillaryClinton: Weve seen too many examples of the struggle to live freely, openly, and without fear being marked by violence. We have',
#                '0'],
#               ['Ohio supports our vulnerable foster care youth so that they can reach their full potential.\rhttps://t.co/XuhW5QVDEp',
#                '1'],
#               ['#News Trump and Clinton Take Up Arms - Donald successfully spoke in full sentences but may be confused about hi... https://t.co/LclaAgVw0F',
#                '-1'],
#               ['You can say that again, @timkaine. https://t.co/jBFfYdk7o9',
#                '1'],
#               ['Tonette and I cheering the @Packers at Animal Kingdom. https://t.co/pX3mO5H6hx',
#                '1'],
#               ["RT @JoeBiden: We're fighting for the middle-class workers who make America great. Follow along as VP Biden is back in Ohio today. https://t",
#                '1'],
#               ['Today in New York City! https://t.co/CQGz15LlGZ', '1'],
#               ["RT @dallasnews: Dallas Police Officer Michael Krol remembered today for 'contagious laugh' https://t.co/9OUd60RwKn https://t.co/NmSiiTbDfA",
#                '0'],
#               ['#Venezuela opposition leader hit with a pipe in the face https://t.co/qtoMBNvJ6T',
#                '0'],
#               ['New Virginia poll- thank you! We are going to show the whole world that America is back  BIGGER, and BETTER, and S https://t.co/2CikEXb0G7',
#                '1'],
#               ['"You are right about Islamophobia, and it\'s a shame." Donald Trump, who proposed a ban on Muslims entering the U.S. https://t.co/4xDbrBtVjt',
#                '-1'],
#               ['TV Ad WATCH --&gt; https://t.co/RvyhtoDReo #CrookedHillary #TrumpTrain',
#                '-1'],
#               ['Major General Eaton has served 30 years in the military -- and he thinks Donald Trump is unfit to be our president.\rhttps://t.co/Hvyj5CPBlk',
#                '-1'],
#               ["When you can't say it - or see it -- you can't fix it. We will MAKE AMERICA SAFE AGAIN! #ImWithYou #AmericaFirst https://t.co/Vd2A747L29",
#                '1'],
#               ['MAKE AMERICA GREAT AGAIN!\r#AmericaFirst #ImWithYou https://t.co/JIlNW7myEN',
#                '1'],
#               ['In our entire history there hasnt been a less qualified person to become president from a character or policy perspective than Trump.',
#                '-1'],
#               ['RT @GOP: History in the making last night with the official VP nominee @mike_pence at the #RNCinCLE! #TrumpPence16\rhttps://t.co/8SQbagPTAP',
#                '1'],
#               ['RT @HillaryClinton: "All that progress is at stake if we don\'t do the right thing over these last 19 days." @POTUS https://t.co/a5j8nqYXia',
#                '1'],
#               ['@DBloom451 you should join the #TrumpTrain. Sign up today! https://t.co/rpkYQB91Ru',
#                '1'],
#               ['RT @Everytown: Senator @TimKaine is a gunsense champion of the first order. https://t.co/2NTz3KV3oT',
#                '1'],
#               ["RT @fxnopinion: .@RandPaul:  President Obama, what on God's green earth is our policy in Syria?\rhttps://t.co/BoV6hcuG6k",
#                '-1'],
#               ['RT @angelurena: No GSA funding was ever used for a private e-mail server. And the @ClintonFdn never housed a GSA-funded e-mail server, priv',
#                '-1'],
#               ['A reminder: Everyone #Trump has insulted on @twitter since launching his campaign. https://t.co/7d8FrWyWaz',
#                '-1'],
#               ['Join me this Wednesday in Phoenix, Arizona at 6pm! #ImWithYou\rTickets: https://t.co/1jATILh2k7 https://t.co/VwKnxo1TNQ',
#                '1'],
#               ['Dummy writer @tonyschwartz, who wanted to do a second book with me for years (I said no), is now a hostile basket case who feels jilted!',
#                '-1'],
#               ['It is time to stop treating Puerto Rico like a colony and start treating its people as the U.S. citizens they are. https://t.co/3R8kKA05NH',
#                '0'],
#               ['Through an extraordinary grassroots movement we beat back the effort to cut Social Security. \rhttps://t.co/Y07vOl2wUe',
#                '1'],
#               ['Thank you so much again! Sorry we find ourselves so divided with no easy choices. I did the best I could. https://t.co/etUYmXStVs',
#                '0'],
#               ["RT @Arightside: A Trojan Horse: We won't be manipulated by the media anymore. https://t.co/eMA8oxTbKK",
#                '0'],
#               ["RT @WHAS11Sara: It's busy inside the Lou. campaign HQ for @RandPaul. They ring a bell every time they get a voter confirmation. @WHAS11 #El",
#                '1'],
#               ['The Republican platform is most \rpro-Israel of all time!',
#                '1'],
#               ["There's a lot of patriotic music out there and that's great, because we should all celebrate our country and our freedom on #IndependenceDay",
#                '1'],
#               ['Trump outrages MSM by agreeing with Hillary Clinton: \r\rhttps://t.co/MoUtcciS9T\r\rOuch!  Egg on the face yet again for the media....omelets!',
#                '-1'],
#               ["The latest Clinton email story just isn't a scandal. Here's why: https://t.co/AuCliPROmF via @paulwaldman1",
#                '-1'],
#               ['Hillary said she was under sniper fire (while surrounded by USSS.) Turned out to be a total lie. She is not fit to https://t.co/hBIrGj21l6',
#                '-1'],
#               ['.@CNN breaks away from #Trump press conference: "This is insane." #TrumpInScotland\rhttps://t.co/ZJ6UHz0dqY',
#                '0'],
#               ['Hillary is so corrupt shed be unbelievable as a TV villain. Heres why shes so dangerous:\rhttps://t.co/EX4HqbQnOg',
#                '-1'],
#               ['Tonight, @HillaryClinton made history. #ImWithHer https://t.co/BHJs2c043G',
#                '1'],
#               ["It's incomprehensible that our laws would protect gun makers over Sandy Hook families. We need to fix this. https://t.co/96uBe92wPi",
#                '-1'],
#               ['RT @rosenbergerlm: When bombs rain down, they rush in. Inspired by the White Helmets &amp; others helping those in need worldwide.  #WHD https:',
#                '0'],
#               ['Donald Trump is unqualified to be Commander-in-Chief. A president doesnt call our military a total disaster. https://t.co/B66Yf4gylz',
#                '-1'],
#               ['The dangers of the TPP are abundant and well-documented. We must do all that we can to #StopTPPNow. https://t.co/rDltJfqKgG',
#                '0'],
#               ['To help the victims &amp; families of the Pulse Nightclub shooting in Orlando, donations can be made here: https://t.co/jvlXqUvaHE',
#                '0'],
#               ['.@HillaryClinton cannot tell the truth. https://t.co/QGDje3AGM5',
#                '-1'],
#               ['Donald Trump has no actual plan to create jobs. https://t.co/pbSjmQN0k3',
#                '-1'],
#               ['.@realDonaldTrump is hoping voters will forget about his sketchy donation, but we cant let him get away with it. https://t.co/PVZR6PlPH2',
#                '-1'],
#               ['.@SenatorReid: #Trumps policy positions are identical to the @GOP platform. https://t.co/P5EVgz5FFN #GOPUnity',
#                '1'],
#               ["RT @TheDemocrats: Creating jobs  it's what Democrats do. In 3 months, let's elect another one: https://t.co/qvnYQxtH0A https://t.co/ywlFN9",
#                '1'],
#               ['.@realDonaldTrump would jeopardize over 200 years of trust. #ImWithHer https://t.co/kP7ak7CP66',
#                '-1'],
#               ['Certainly has been an interesting 24 hours!', '1'],
#               ['"Im asking you to join me, to reject cynicism...to summon whats best in us; to elect Hillary Clinton as the next president @POTUS',
#                '1'],
#               ['Spent Election Day eve campaigning for @HillaryClinton @HillaryforME @emilyanncain all across Maine https://t.co/5txtrky5It',
#                '1'],
#               ['Wow, the @nytimes is losing thousands of subscribers because of their very poor and highly inaccurate coverage of the "Trump phenomena"',
#                '-1'],
#               ['Were launching Spanish-language ads in key battleground states today. Watch What We Stand For here! https://t.co/KXDjfEdQX1',
#                '1'],
#               ['RT @HenryJGomez: Cleveland\'s @chefsymon on @realDonaldTrump: \'Not a chance I\'d let him into one of my restaurants." https://t.co/ZXbSPkXKGr',
#                '-1'],
#               ["Flags at half-staff tomorrow honor America's fallen firefighters, heroes who gave their all in serving others. https://t.co/yQsp8rMIGY",
#                '0'],
#               ["Doppelgnger??!!  Joe Maddon (Cub's manager &amp; Tommy Orr neighbor extraordinaire) #game7 https://t.co/FdBiwsIryP",
#                '0'],
#               ['As expected, the media is very much against me. Their dishonesty is amazing but, just like our big wins in the primaries, we will win!',
#                '1'],
#               ['On immigration -- Illegal immigrants should be forced to  register with the govt, pay taxes and get to know the IRS like everyone else.',
#                '0'],
#               ['RT @michaelruane: Remains of Pearl Harbors hero priest identified after almost 75 years - The Washington Post https://t.co/gRB7JlQbLL',
#                '0'],
#               ['Los trabajadores no han recibido un aumento en aosHillary tiene un plan para subir los salarios. https://t.co/ODUmS9rO2p',
#                'NA'],
#               ['When millions of people stand together we win. Take a stand today to protect health care for all. https://t.co/oVtr4LCpHV',
#                '1'],
#               ['Fossil fuel companies are willing to destroy the planet for short-term profits. That is just incomprehensible. Incomprehensible.',
#                '-1'],
#               ...]})

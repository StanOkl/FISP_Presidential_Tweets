# %%
#!/usr/bin/env python
# encoding: utf-8
 
import tweepy #https://github.com/tweepy/tweepy
import csv
import os
import pandas as pd
import time 
 
#Twitter API credentials
consumer_key = "XXXXXXXXXXXX"
consumer_secret = "XXXXXXXXXXXX"
access_key = "XXXXXXXXXXXX"
access_secret = "XXXXXXXXXXXX"
 
os.chdir('YOUR DIRECTORY HERE')


df = pd.read_csv('PresTwitters.csv')
cand= df.Twitter.astype(str).tolist()   
 
def get_all_tweets(screen_name):
	#Twitter only allows access to a users most recent 3240 tweets with this method
	
	#authorize twitter, initialize tweepy
	auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
	auth.set_access_token(access_key, access_secret)
	api = tweepy.API(auth)
	
    	#initialize a list to hold all the tweepy Tweets
	alltweets = []	
	
	#make initial request for most recent tweets (200 is the maximum allowed count)
	new_tweets = api.user_timeline(screen_name = screen_name,count=200)
	
	#save most recent tweets
	alltweets.extend(new_tweets)
	
	#save the id of the oldest tweet less one
	oldest = alltweets[-1].id - 1
	
	#keep grabbing tweets until there are no tweets left to grab
	while len(new_tweets) > 0:
		print "getting tweets before %s" % (oldest)
		
		#all subsiquent requests use the max_id param to prevent duplicates
		new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
		
		#save most recent tweets
		alltweets.extend(new_tweets)
		
		#update the id of the oldest tweet less one
		oldest = alltweets[-1].id - 1
		
		print "...%s tweets downloaded so far" % (len(alltweets))
	
	#transform the tweepy tweets into a 2D array that will populate the csv	
	outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
	
	#write the csv	
	with open('%s_tweets.csv' % screen_name, 'wb') as f:
		writer = csv.writer(f)
		writer.writerow(["id","created_at","text"])
		writer.writerows(outtweets)
	    
	pass

if __name__ == '__main__':
	#pass in the username of the account you want to download
    for i in range(len(cand)):
        get_all_tweets(cand[i])
        #Putting in 80s delay between calls to avoid API limit
        time.sleep(80)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version a but this version of numpy is 9
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version a but this version of numpy is 9
# getting tweets before 712637597902831615
# ...400 tweets downloaded so far
# getting tweets before 709810352662429695
# ...600 tweets downloaded so far
# getting tweets before 706670597556858884
# ...798 tweets downloaded so far
# getting tweets before 704467840510902271
# ...998 tweets downloaded so far
# getting tweets before 701901178100056064
# ...1198 tweets downloaded so far
# getting tweets before 699614719456387071
# ...1398 tweets downloaded so far
# getting tweets before 696808045511368703
# ...1598 tweets downloaded so far
# getting tweets before 694588666245701631
# ...1798 tweets downloaded so far
# getting tweets before 692788243318722560
# ...1997 tweets downloaded so far
# getting tweets before 689913851752640516
# ...2197 tweets downloaded so far
# getting tweets before 687117126797230080
# ...2397 tweets downloaded so far
# getting tweets before 684457857820028927
# ...2597 tweets downloaded so far
# getting tweets before 681278691477946367
# ...2797 tweets downloaded so far
# getting tweets before 677548645265203200
# ...2997 tweets downloaded so far
# getting tweets before 674232446725042175
# ...3197 tweets downloaded so far
# getting tweets before 669641863012446207
# ...3241 tweets downloaded so far
# getting tweets before 668899840630198272
# ...3241 tweets downloaded so far
# getting tweets before 711304448308449279
# ...400 tweets downloaded so far
# getting tweets before 706961192552701951
# ...600 tweets downloaded so far
# getting tweets before 703302342951747585
# ...799 tweets downloaded so far
# getting tweets before 699701016506327040
# ...999 tweets downloaded so far
# getting tweets before 696412008971763711
# ...1199 tweets downloaded so far
# getting tweets before 694257282608160768
# ...1399 tweets downloaded so far
# getting tweets before 690945816211656703
# ...1599 tweets downloaded so far
# getting tweets before 687273691827273727
# ...1799 tweets downloaded so far
# getting tweets before 681281190783926271
# ...1999 tweets downloaded so far
# getting tweets before 675111605303160832
# ...2199 tweets downloaded so far
# getting tweets before 668082922000400383
# ...2399 tweets downloaded so far
# getting tweets before 664285163912691711
# ...2599 tweets downloaded so far
# getting tweets before 659810143555723264
# ...2799 tweets downloaded so far
# getting tweets before 657221810325336063
# ...2999 tweets downloaded so far
# getting tweets before 653677442347986943
# ...3199 tweets downloaded so far
# getting tweets before 647108816983601152
# ...3199 tweets downloaded so far
# getting tweets before 712040332993626115
# ...400 tweets downloaded so far
# getting tweets before 708145957842472963
# ...600 tweets downloaded so far
# getting tweets before 705900880768462847
# ...800 tweets downloaded so far
# getting tweets before 703255337307135999
# ...1000 tweets downloaded so far
# getting tweets before 700502807586193407
# ...1200 tweets downloaded so far
# getting tweets before 697522726693507071
# ...1400 tweets downloaded so far
# getting tweets before 696017030185676799
# ...1600 tweets downloaded so far
# getting tweets before 692896537991467007
# ...1800 tweets downloaded so far
# getting tweets before 689158936122015743
# ...2000 tweets downloaded so far
# getting tweets before 685170062093860865
# ...2200 tweets downloaded so far
# getting tweets before 675426057097449472
# ...2400 tweets downloaded so far
# getting tweets before 666651589399216127
# ...2600 tweets downloaded so far
# getting tweets before 659560279814967295
# ...2798 tweets downloaded so far
# getting tweets before 650053908027604991
# ...2998 tweets downloaded so far
# getting tweets before 640609690645344255
# ...3198 tweets downloaded so far
# getting tweets before 628375557131010047
# ...3209 tweets downloaded so far
# getting tweets before 627634677562519551
# ...3209 tweets downloaded so far
# getting tweets before 710453513155960833
# ...400 tweets downloaded so far
# getting tweets before 705793784093745152
# ...600 tweets downloaded so far
# getting tweets before 702180291448680447
# ...800 tweets downloaded so far
# getting tweets before 698179564107886591
# ...1000 tweets downloaded so far
# getting tweets before 693056021896519679
# ...1200 tweets downloaded so far
# getting tweets before 689913293759115263
# ...1400 tweets downloaded so far
# getting tweets before 684198370349572096
# ...1600 tweets downloaded so far
# getting tweets before 679416309545873408
# ...1800 tweets downloaded so far
# getting tweets before 675756151322058752
# ...2000 tweets downloaded so far
# getting tweets before 672792662865506304
# ...2200 tweets downloaded so far
# getting tweets before 668827894630731775
# ...2400 tweets downloaded so far
# getting tweets before 665592708375822335
# ...2600 tweets downloaded so far
# getting tweets before 662192823282847744
# ...2800 tweets downloaded so far
# getting tweets before 659610110940086271
# ...3000 tweets downloaded so far
# getting tweets before 656144381993463807
# ...3200 tweets downloaded so far
# getting tweets before 654098496417603583
# ...3231 tweets downloaded so far
# getting tweets before 653898481501872127
# ...3231 tweets downloaded so far
# getting tweets before 713866902225879039
# ...399 tweets downloaded so far
# getting tweets before 711887623451586559
# ...599 tweets downloaded so far
# getting tweets before 709367081544716287
# ...799 tweets downloaded so far
# getting tweets before 707273330814922751
# ...998 tweets downloaded so far
# getting tweets before 705217810088095745
# ...1198 tweets downloaded so far
# getting tweets before 703335747865223167
# ...1397 tweets downloaded so far
# getting tweets before 701469903795023871
# ...1597 tweets downloaded so far
# getting tweets before 699795433384599551
# ...1797 tweets downloaded so far
# getting tweets before 697918834812985343
# ...1997 tweets downloaded so far
# getting tweets before 696121301518278659
# ...2196 tweets downloaded so far
# getting tweets before 694183280019525631
# ...2396 tweets downloaded so far
# getting tweets before 692899587778961408
# ...2594 tweets downloaded so far
# getting tweets before 690958875298631679
# ...2794 tweets downloaded so far
# getting tweets before 688085676974313471
# ...2994 tweets downloaded so far
# getting tweets before 685858255847882751
# ...3194 tweets downloaded so far
# getting tweets before 684152106434064383
# ...3241 tweets downloaded so far
# getting tweets before 683355595550789632
# ...3241 tweets downloaded so far
